# %% [markdown]
# #

# %%
# Standard library imports
import os
import shutil
import glob
from pathlib import Path


# Third-party library imports
import micom
from micom import Community
from cobra import Reaction, Metabolite, Model
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import cobra

# %%
# params
model_db_path = Path("./models/")       # Replace with your actual model directory path
adjusted_models_path = Path("./adjusted_models")  # Replace with your desired output directory path

# Define the medium composition
medium = {
    'EX_cpd00058_e0': 1000.0,   # Cu2+
    'EX_cpd00104_e0': 1000.0,   # Biotin
    'EX_cpd00063_e0': 1000.0,   # Ca2+
    'EX_cpd00099_e0': 1000.0,   # Cl-
    'EX_cpd00149_e0': 1000.0,   # Cobalt
    'EX_cpd10515_e0': 1000.0,   # Fe2+
    'EX_cpd10516_e0': 1000.0,   # Fe3+
    'EX_cpd00067_e0': 1000.0,   # H+
    'EX_cpd00001_e0': 1000.0,   # H2O
    'EX_cpd00205_e0': 1000.0,   # K+
    'EX_cpd00254_e0': 1000.0,   # Mg
    'EX_cpd00030_e0': 1000.0,   # Mn2+
    'EX_cpd11574_e0': 1000.0,   # Molybdate
    'EX_cpd00244_e0': 1000.0,   # Nickel
    'EX_cpd00209_e0': 1000.0,   # Nitrate
    'EX_cpd00009_e0': 1000.0,   # Phosphate
    'EX_cpd00048_e0': 1000.0,   # Sulfate
    'EX_cpd00305_e0': 1000.0,   # Thiamin
    'EX_cpd00034_e0': 1000.0,   # Zn2+
    'EX_cpd11632_e0': 1000.0,   # Photon
    'EX_cpd00011_e0': 1000.0,   # CO2
    'EX_cpd00007_e0': 1000.0,   # O2
    'EX_cpd00528_e0': 1000.0,   # N2
}

# %%
# ----------------------------
# Configure Logging
# ----------------------------

# First, get the root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Set the desired logging level

# Remove any existing handlers to prevent duplicate logs
if logger.hasHandlers():
    logger.handlers.clear()

# Create a file handler to save logs to a file
file_handler = logging.FileHandler('model_processing.log')
file_handler.setLevel(logging.INFO)

# Create a stream handler to print logs to the Jupyter cell
stream_handler = logging.StreamHandler()
stream_handler.setLevel(logging.INFO)

# Define a common formatter
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Assign the formatter to both handlers
file_handler.setFormatter(formatter)
stream_handler.setFormatter(formatter)

# Add both handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(stream_handler)



def adjust_medium(model, medium):
    """
    Adjust the medium for the given model based on available exchange reactions.
    """
    adjusted_medium = {}
    available_exchanges = {rxn.id for rxn in model.exchanges}
    for rxn_id, value in medium.items():
        if rxn_id in available_exchanges:
            adjusted_medium[rxn_id] = value
        else:
            logging.warning(f"Exchange reaction {rxn_id} not found in model {model.id}")
    return adjusted_medium

def add_exchange_reaction(model, metabolite_id_base, lower_bound=-1000, upper_bound=1000):
    """
    Adds an exchange reaction for a metabolite, creating external and transport reactions if necessary.
    """
    # Build metabolite IDs
    internal_met_id = f"M_{metabolite_id_base}_c0"
    external_met_id = f"M_{metabolite_id_base}_e0"
    exchange_rxn_id = f"EX_M_{metabolite_id_base}_e0"
    transport_rxn_id = f"TRANS_M_{metabolite_id_base}"
    
    # Check if the internal metabolite exists
    try:
        internal_met = model.metabolites.get_by_id(internal_met_id)
    except KeyError:
        logging.error(f"Internal metabolite {internal_met_id} not found in model {model.id}. Cannot proceed.")
        return
    
    # Check if the external metabolite exists; if not, create it
    external_met = model.metabolites.get_by_id(external_met_id, None)
    if external_met is None:
        external_met = Metabolite(
            id=external_met_id,
            formula=internal_met.formula,
            name=internal_met.name,
            compartment='e0'
        )
        model.add_metabolites([external_met])
        logging.info(f"Added external metabolite {external_met_id} to model {model.id}")
    
    # Add the transport reaction if it doesn't exist
    if transport_rxn_id not in model.reactions:
        transport_rxn = Reaction(id=transport_rxn_id)
        transport_rxn.name = f"Transport of {internal_met.name}"
        transport_rxn.lower_bound = -1000
        transport_rxn.upper_bound = 1000
        transport_rxn.add_metabolites({internal_met: -1, external_met: 1})
        model.add_reactions([transport_rxn])
        logging.info(f"Added transport reaction {transport_rxn_id} to model {model.id}")
    
    # Add the exchange reaction if it doesn't exist
    if exchange_rxn_id not in model.reactions:
        exchange_rxn = Reaction(id=exchange_rxn_id)
        exchange_rxn.name = f"Exchange of {external_met.name}"
        exchange_rxn.lower_bound = lower_bound
        exchange_rxn.upper_bound = upper_bound
        exchange_rxn.add_metabolites({external_met: -1})
        model.add_reactions([exchange_rxn])
        logging.info(f"Added exchange reaction {exchange_rxn_id} to model {model.id}")
    else:
        logging.info(f"Exchange reaction {exchange_rxn_id} already exists in model {model.id}")

def add_all_exchange_reactions(model, medium):
    """
    Add exchange reactions for all components defined in the medium.
    """
    for rxn_id in medium.keys():
        if rxn_id not in model.reactions:
            # Infer metabolite ID by removing 'EX_' prefix
            if rxn_id.startswith('EX_'):
                metabolite_id = rxn_id[3:]
                if metabolite_id in model.metabolites:
                    add_exchange_reaction(model, metabolite_id, reaction_id=rxn_id)
                else:
                    logging.warning(f"Metabolite {metabolite_id} corresponding to {rxn_id} not found in model {model.id}. Exchange reaction {rxn_id} not added.")
            else:
                logging.warning(f"Reaction ID {rxn_id} does not follow the 'EX_' prefix convention. Skipping.")

def process_model(model_path, output_dir, medium):
    """
    Load a model, adjust it by adding exchange reactions for all medium components,
    set the medium, optimize the model, and save the adjusted model to the output directory.
    """
    try:
        # Load the model using micom.util.load_model (keeping it as is)
        model = micom.util.load_model(str(model_path))
        logging.info(f"\nProcessing model: {model.id}")

        # Add exchange reactions for all medium components
        add_all_exchange_reactions(model, medium)

        # Adjust the medium
        adjusted_medium = adjust_medium(model, medium)
        model.medium = adjusted_medium

        # Optional: Optimize the model to ensure it can grow
        solution = model.optimize()
        logging.info(f"Model {model.id} growth rate after adjustment: {solution.objective_value}")

        # Save the adjusted model using the existing save function
        output_model_path = output_dir / model_path.name
        write_sbml_model(model, output_model_path)  # Keeping the saving function as is
        logging.info(f"Saved adjusted model to {output_model_path}")

    except Exception as e:
        logging.error(f"Failed to process model {model_path.name}: {e}")


"""
Main function to process all models in the specified directory.
"""
# Iterate through all files in the model_db_path
for model_file in model_db_path.iterdir():
    # Check if the file is an XML file (common format for metabolic models)
    if model_file.suffix.lower() in ['.xml']:
        process_model(model_file, adjusted_models_path, medium)
    else:
        logging.warning(f"Skipping unsupported file format: {model_file.name}")

logging.info("\nAll models have been processed.")

# ----------------------------
# Copy Manifest File to the Output Directory
# ----------------------------

# Define the manifest file name (adjust if your manifest file has a different name)
manifest_filename = "manifest.csv"  # Replace with the actual manifest file name if different

# Define the source and destination paths for the manifest file
source_manifest = model_db_path / manifest_filename
destination_manifest = adjusted_models_path / manifest_filename

# Check if the manifest file exists in the source directory
if source_manifest.exists():
    try:
        shutil.copy2(source_manifest, destination_manifest)
        logging.info(f"Copied manifest file to {destination_manifest}")
    except Exception as e:
        logging.error(f"Failed to copy manifest file: {e}")
else:
    logging.warning(f"Manifest file {manifest_filename} not found in {model_db_path}. No manifest copied.")
# Out:
# 2024-11-11 09:32:13,353 - INFO - reading model from models/bin.5.xml
# 2024-11-11 09:32:14,913 - INFO - The current solver interface glpk doesn't support setting the optimality tolerance.
# 2024-11-11 09:32:16,181 - INFO -
# Processing model: bin_5
# 2024-11-11 09:32:16,184 - WARNING - Metabolite cpd00104_e0 corresponding to EX_cpd00104_e0 not found in model bin_5. Exchange reaction EX_cpd00104_e0 not added.
# 2024-11-11 09:32:16,194 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 09:32:16,204 - WARNING - Exchange reaction EX_cpd00104_e0 not found in model bin_5
# 2024-11-11 09:32:16,210 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 09:32:16,322 - INFO - Model bin_5 growth rate after adjustment: 0.0
# 2024-11-11 09:32:18,274 - INFO - Saved adjusted model to adjusted_models/bin.5.xml
# 2024-11-11 09:32:18,361 - INFO - reading model from models/bin.6.xml
# 2024-11-11 09:32:19,787 - INFO - The current solver interface glpk doesn't support setting the optimality tolerance.
# 2024-11-11 09:32:20,945 - INFO -
# Processing model: bin_6
# 2024-11-11 09:32:20,948 - WARNING - Metabolite cpd00104_e0 corresponding to EX_cpd00104_e0 not found in model bin_6. Exchange reaction EX_cpd00104_e0 not added.
# 2024-11-11 09:32:20,957 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 09:32:20,966 - WARNING - Exchange reaction EX_cpd00104_e0 not found in model bin_6
# 2024-11-11 09:32:20,972 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 09:32:21,146 - INFO - Model bin_6 growth rate after adjustment: 2.9808737165594477
# 2024-11-11 09:32:22,999 - INFO - Saved adjusted model to adjusted_models/bin.6.xml
# 2024-11-11 09:32:23,040 - WARNING - Skipping unsupported file format: .ipynb_checkpoints
# 2024-11-11 09:32:23,041 - WARNING - Skipping unsupported file format: manifest.csv
# 2024-11-11 09:32:23,043 - INFO -
# All models have been processed.
# 2024-11-11 09:32:23,046 - INFO - Copied manifest file to adjusted_models/manifest.csv

# %%
model = micom.util.load_model(str("./adjusted_models/bin.6.xml"))
#adjusted_medium = adjust_medium(model, medium)
model.medium = adjusted_medium
# Optional: Optimize the model to ensure it can grow
solution = model.optimize()
solution.objective_value

# Print compartments
print("Compartments in the model:")
print(model.compartments)
# Out:
# 2024-11-11 09:34:19,547 - INFO - reading model from ./adjusted_models/bin.6.xml
# 2024-11-11 09:34:20,893 - INFO - The current solver interface glpk doesn't support setting the optimality tolerance.
# 2024-11-11 09:34:24,323 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# Compartments in the model:
# {'c0': '', 'e0': '', 'p0': ''}

# %% [markdown]
# # get comunity data

# %%
# Combine Individual Models into a Community Model
import pandas as pd
# Create the taxonomy DataFrame
taxonomy = pd.DataFrame({
    'id': ['bin.5','bin.6'],
    'abundance': [0.5,0.5],
    'phylum': ['Firmicutes','Proteobacteria']
})

# Specify the directory containing your model files

# Create the community model
community = Community (
    taxonomy,
     model_db=str(adjusted_models_path)
)
# Out:
# 2024-11-11 10:18:16,767 - INFO - The current solver interface glpk doesn't support setting the optimality tolerance.
# 2024-11-11 10:18:16,769 - INFO - building new micom model None.
# 2024-11-11 10:18:16,770 - INFO - using the cplex solver.
# 2024-11-11 10:18:16,780 - INFO - 0 individuals with abundances below threshold
# 2024-11-11 10:18:16,791 - INFO - Matched 100% of total abundance in model DB.
# Output()
# 2024-11-11 10:18:16,803 - INFO - reading model from adjusted_models/bin.5.xml
# 2024-11-11 10:18:18,280 - INFO - The current solver interface glpk doesn't support setting the optimality tolerance.
# 2024-11-11 10:18:19,601 - INFO - converting IDs for bin_5
# 2024-11-11 10:18:19,611 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:18:19,611 - INFO - Identified e0 as the external compartment for bin_5. If that is wrong you may be in trouble...
# 2024-11-11 10:18:22,105 - INFO - adding reactions for bin_5 to community
# 2024-11-11 10:18:22,833 - INFO - adding metabolite cpd00001_m to external medium
# 2024-11-11 10:18:22,836 - INFO - adding metabolite cpd00418_m to external medium
# 2024-11-11 10:18:22,837 - INFO - adding metabolite cpd00075_m to external medium
# 2024-11-11 10:18:22,839 - INFO - adding metabolite cpd00009_m to external medium
# 2024-11-11 10:18:22,841 - INFO - adding metabolite cpd00023_m to external medium
# 2024-11-11 10:18:22,842 - INFO - adding metabolite cpd00027_m to external medium
# 2024-11-11 10:18:22,844 - INFO - adding metabolite cpd00028_m to external medium
# 2024-11-11 10:18:22,846 - INFO - adding metabolite cpd00030_m to external medium
# 2024-11-11 10:18:22,848 - INFO - adding metabolite cpd00034_m to external medium
# 2024-11-11 10:18:22,850 - INFO - adding metabolite cpd00039_m to external medium
# 2024-11-11 10:18:22,852 - INFO - adding metabolite cpd00041_m to external medium
# 2024-11-11 10:18:22,855 - INFO - adding metabolite cpd00048_m to external medium
# 2024-11-11 10:18:22,856 - INFO - adding metabolite cpd00051_m to external medium
# 2024-11-11 10:18:22,858 - INFO - adding metabolite cpd00053_m to external medium
# 2024-11-11 10:18:22,859 - INFO - adding metabolite cpd00064_m to external medium
# 2024-11-11 10:18:22,861 - INFO - adding metabolite cpd00073_m to external medium
# 2024-11-11 10:18:22,863 - INFO - adding metabolite cpd00098_m to external medium
# 2024-11-11 10:18:22,865 - INFO - adding metabolite cpd00105_m to external medium
# 2024-11-11 10:18:23,114 - INFO - adding metabolite cpd01024_m to external medium
# 2024-11-11 10:18:23,116 - INFO - adding metabolite cpd00204_m to external medium
# 2024-11-11 10:18:23,118 - INFO - adding metabolite cpd00116_m to external medium
# 2024-11-11 10:18:23,120 - INFO - adding metabolite cpd00528_m to external medium
# 2024-11-11 10:18:23,122 - INFO - adding metabolite cpd11632_m to external medium
# 2024-11-11 10:18:23,124 - INFO - adding metabolite cpd03662_m to external medium
# 2024-11-11 10:18:23,126 - INFO - adding metabolite cpd00178_m to external medium
# 2024-11-11 10:18:23,127 - INFO - adding metabolite cpd01618_m to external medium
# 2024-11-11 10:18:23,129 - INFO - adding metabolite cpd00276_m to external medium
# 2024-11-11 10:18:23,131 - INFO - adding metabolite cpd00107_m to external medium
# 2024-11-11 10:18:23,133 - INFO - adding metabolite cpd01017_m to external medium
# 2024-11-11 10:18:23,135 - INFO - adding metabolite cpd00210_m to external medium
# 2024-11-11 10:18:23,137 - INFO - adding metabolite cpd15605_m to external medium
# 2024-11-11 10:18:23,139 - INFO - adding metabolite cpd00122_m to external medium
# 2024-11-11 10:18:23,141 - INFO - adding metabolite cpd00322_m to external medium
# 2024-11-11 10:18:23,143 - INFO - adding metabolite cpd00793_m to external medium
# 2024-11-11 10:18:23,145 - INFO - adding metabolite cpd00099_m to external medium
# 2024-11-11 10:18:23,146 - INFO - adding metabolite cpd00010_m to external medium
# 2024-11-11 10:18:23,148 - INFO - adding metabolite cpd00038_m to external medium
# 2024-11-11 10:18:23,151 - INFO - adding metabolite cpd00380_m to external medium
# 2024-11-11 10:18:23,153 - INFO - adding metabolite cpd00060_m to external medium
# 2024-11-11 10:18:23,155 - INFO - adding metabolite cpd00366_m to external medium
# 2024-11-11 10:18:23,157 - INFO - adding metabolite cpd00222_m to external medium
# 2024-11-11 10:18:23,159 - INFO - adding metabolite cpd00081_m to external medium
# 2024-11-11 10:18:23,161 - INFO - adding metabolite cpd00017_m to external medium
# 2024-11-11 10:18:23,162 - INFO - adding metabolite cpd00130_m to external medium
# 2024-11-11 10:18:23,164 - INFO - adding metabolite cpd00653_m to external medium
# 2024-11-11 10:18:23,166 - INFO - reading model from adjusted_models/bin.6.xml
# 2024-11-11 10:18:24,499 - INFO - The current solver interface glpk doesn't support setting the optimality tolerance.
# 2024-11-11 10:18:25,764 - INFO - converting IDs for bin_6
# 2024-11-11 10:18:25,774 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:18:25,778 - INFO - Identified e0 as the external compartment for bin_6. If that is wrong you may be in trouble...
# 2024-11-11 10:18:27,851 - INFO - adding reactions for bin_6 to community
# 2024-11-11 10:18:28,758 - INFO - updating import rate for external metabolite cpd00009_m
# 2024-11-11 10:18:28,761 - INFO - updating import rate for external metabolite cpd00023_m
# 2024-11-11 10:18:28,762 - INFO - updating import rate for external metabolite cpd00027_m
# 2024-11-11 10:18:28,764 - INFO - updating import rate for external metabolite cpd00028_m
# 2024-11-11 10:18:28,769 - INFO - updating import rate for external metabolite cpd00030_m
# 2024-11-11 10:18:28,771 - INFO - updating import rate for external metabolite cpd00034_m
# 2024-11-11 10:18:28,773 - INFO - updating import rate for external metabolite cpd00039_m
# 2024-11-11 10:18:28,775 - INFO - updating import rate for external metabolite cpd00041_m
# 2024-11-11 10:18:28,776 - INFO - updating import rate for external metabolite cpd00048_m
# 2024-11-11 10:18:28,778 - INFO - updating import rate for external metabolite cpd00051_m
# 2024-11-11 10:18:28,780 - INFO - updating import rate for external metabolite cpd00053_m
# 2024-11-11 10:18:28,781 - INFO - updating import rate for external metabolite cpd00064_m
# 2024-11-11 10:18:28,783 - INFO - updating import rate for external metabolite cpd00098_m
# 2024-11-11 10:18:28,785 - INFO - updating import rate for external metabolite cpd00105_m
# 2024-11-11 10:18:28,786 - INFO - updating import rate for external metabolite cpd00107_m
# 2024-11-11 10:18:28,788 - INFO - updating import rate for external metabolite cpd00108_m
# 2024-11-11 10:18:28,789 - INFO - updating import rate for external metabolite cpd00118_m
# 2024-11-11 10:18:28,791 - INFO - updating import rate for external metabolite cpd00119_m
# 2024-11-11 10:18:28,793 - INFO - updating import rate for external metabolite cpd00129_m
# 2024-11-11 10:18:28,795 - INFO - updating import rate for external metabolite cpd00149_m
# 2024-11-11 10:18:28,796 - INFO - updating import rate for external metabolite cpd00154_m
# 2024-11-11 10:18:28,798 - INFO - updating import rate for external metabolite cpd00156_m
# 2024-11-11 10:18:28,799 - INFO - updating import rate for external metabolite cpd00161_m
# 2024-11-11 10:18:28,801 - INFO - updating import rate for external metabolite cpd00179_m
# 2024-11-11 10:18:28,803 - INFO - updating import rate for external metabolite cpd00224_m
# 2024-11-11 10:18:28,804 - INFO - updating import rate for external metabolite cpd00244_m
# 2024-11-11 10:18:28,806 - INFO - updating import rate for external metabolite cpd00264_m
# 2024-11-11 10:18:28,807 - INFO - updating import rate for external metabolite cpd00268_m
# 2024-11-11 10:18:28,809 - INFO - updating import rate for external metabolite cpd00322_m
# 2024-11-11 10:18:28,811 - INFO - updating import rate for external metabolite cpd00540_m
# 2024-11-11 10:18:28,812 - INFO - adding metabolite cpd03724_m to external medium
# 2024-11-11 10:18:28,815 - INFO - updating import rate for external metabolite cpd10516_m
# 2024-11-11 10:18:28,817 - INFO - updating import rate for external metabolite cpd00067_m
# 2024-11-11 10:18:28,819 - INFO - updating import rate for external metabolite cpd00367_m
# 2024-11-11 10:18:28,820 - INFO - updating import rate for external metabolite cpd00311_m
# 2024-11-11 10:18:28,821 - INFO - updating import rate for external metabolite cpd00060_m
# 2024-11-11 10:18:28,823 - INFO - updating import rate for external metabolite cpd00220_m
# 2024-11-11 10:18:28,824 - INFO - updating import rate for external metabolite cpd00084_m
# 2024-11-11 10:18:28,825 - INFO - updating import rate for external metabolite cpd00971_m
# 2024-11-11 10:18:28,826 - INFO - updating import rate for external metabolite cpd00054_m
# 2024-11-11 10:18:28,828 - INFO - updating import rate for external metabolite cpd00246_m
# 2024-11-11 10:18:28,829 - INFO - updating import rate for external metabolite cpd00182_m
# 2024-11-11 10:18:28,831 - INFO - updating import rate for external metabolite cpd00013_m
# 2024-11-11 10:18:28,832 - INFO - updating import rate for external metabolite cpd00020_m
# 2024-11-11 10:18:28,834 - INFO - updating import rate for external metabolite cpd00029_m
# 2024-11-11 10:18:28,835 - INFO - updating import rate for external metabolite cpd04098_m
# 2024-11-11 10:18:28,837 - INFO - updating import rate for external metabolite cpd00063_m
# 2024-11-11 10:18:28,839 - INFO - updating import rate for external metabolite cpd01012_m
# 2024-11-11 10:18:28,840 - INFO - updating import rate for external metabolite cpd00058_m
# 2024-11-11 10:18:28,842 - INFO - updating import rate for external metabolite cpd00363_m
# 2024-11-11 10:18:28,844 - INFO - updating import rate for external metabolite cpd10515_m
# 2024-11-11 10:18:28,845 - INFO - updating import rate for external metabolite cpd00082_m
# 2024-11-11 10:18:28,847 - INFO - updating import rate for external metabolite cpd00106_m
# 2024-11-11 10:18:28,849 - INFO - updating import rate for external metabolite cpd00121_m
# 2024-11-11 10:18:28,850 - INFO - updating import rate for external metabolite cpd00205_m
# 2024-11-11 10:18:28,852 - INFO - updating import rate for external metabolite cpd00208_m
# 2024-11-11 10:18:28,853 - INFO - updating import rate for external metabolite cpd01262_m
# 2024-11-11 10:18:28,855 - INFO - updating import rate for external metabolite cpd11574_m
# 2024-11-11 10:18:28,857 - INFO - updating import rate for external metabolite cpd00075_m
# 2024-11-11 10:18:28,858 - INFO - updating import rate for external metabolite cpd00209_m
# 2024-11-11 10:18:28,860 - INFO - updating import rate for external metabolite cpd01132_m
# 2024-11-11 10:18:28,861 - INFO - updating import rate for external metabolite cpd00396_m
# 2024-11-11 10:18:28,863 - INFO - updating import rate for external metabolite cpd00036_m
# 2024-11-11 10:18:28,865 - INFO - updating import rate for external metabolite cpd01217_m
# 2024-11-11 10:18:28,866 - INFO - updating import rate for external metabolite cpd00751_m
# 2024-11-11 10:18:28,868 - INFO - updating import rate for external metabolite cpd00035_m
# 2024-11-11 10:18:28,873 - INFO - updating import rate for external metabolite cpd00132_m
# 2024-11-11 10:18:28,875 - INFO - updating import rate for external metabolite cpd00099_m
# 2024-11-11 10:18:28,877 - INFO - updating import rate for external metabolite cpd00277_m
# 2024-11-11 10:18:28,878 - INFO - updating import rate for external metabolite cpd01107_m
# 2024-11-11 10:18:28,880 - INFO - updating import rate for external metabolite cpd01741_m
# 2024-11-11 10:18:28,882 - INFO - updating import rate for external metabolite cpd03847_m
# 2024-11-11 10:18:28,884 - INFO - updating import rate for external metabolite cpd15298_m
# 2024-11-11 10:18:28,886 - INFO - updating import rate for external metabolite cpd00214_m
# 2024-11-11 10:18:28,888 - INFO - updating import rate for external metabolite cpd15237_m
# 2024-11-11 10:18:28,890 - INFO - updating import rate for external metabolite cpd01080_m
# 2024-11-11 10:18:28,891 - INFO - updating import rate for external metabolite cpd15269_m
# 2024-11-11 10:18:28,893 - INFO - updating import rate for external metabolite cpd01113_m
# 2024-11-11 10:18:28,894 - INFO - updating import rate for external metabolite cpd03846_m
# 2024-11-11 10:18:28,895 - INFO - updating import rate for external metabolite cpd00531_m
# 2024-11-11 10:18:28,896 - INFO - updating import rate for external metabolite cpd03587_m
# 2024-11-11 10:18:28,898 - INFO - updating import rate for external metabolite cpd01399_m
# 2024-11-11 10:18:28,899 - INFO - updating import rate for external metabolite cpd00254_m
# 2024-11-11 10:18:28,901 - INFO - updating import rate for external metabolite cpd00305_m
# 2024-11-11 10:18:28,902 - INFO - updating import rate for external metabolite cpd04097_m
# 2024-11-11 10:18:28,904 - INFO - updating import rate for external metabolite cpd00185_m
# 2024-11-11 10:18:28,905 - INFO - updating import rate for external metabolite cpd00010_m
# 2024-11-11 10:18:28,907 - INFO - updating import rate for external metabolite cpd15494_m
# 2024-11-11 10:18:28,909 - INFO - updating import rate for external metabolite cpd00794_m
# 2024-11-11 10:18:28,910 - INFO - updating import rate for external metabolite cpd00033_m
# 2024-11-11 10:18:28,912 - INFO - updating import rate for external metabolite cpd11976_m
# 2024-11-11 10:18:28,914 - INFO - updating import rate for external metabolite cpd00133_m
# 2024-11-11 10:18:28,915 - INFO - updating import rate for external metabolite cpd00006_m
# 2024-11-11 10:18:28,917 - INFO - updating import rate for external metabolite cpd11451_m
# 2024-11-11 10:18:28,919 - INFO - updating import rate for external metabolite cpd11606_m
# 2024-11-11 10:18:28,920 - INFO - updating import rate for external metabolite cpd17026_m
# 2024-11-11 10:18:28,922 - INFO - updating import rate for external metabolite cpd17027_m
# 2024-11-11 10:18:28,923 - INFO - adding metabolite cpd01048_m to external medium
# 2024-11-11 10:18:28,926 - INFO - updating import rate for external metabolite cpd00281_m
# 2024-11-11 10:18:28,928 - INFO - updating import rate for external metabolite cpd00138_m
# 2024-11-11 10:18:28,929 - INFO - updating import rate for external metabolite cpd00314_m
# 2024-11-11 10:18:28,931 - INFO - updating import rate for external metabolite cpd01133_m
# 2024-11-11 10:18:28,933 - INFO - adding metabolite cpd02733_m to external medium
# 2024-11-11 10:18:28,935 - INFO - updating import rate for external metabolite cpd01354_m
# 2024-11-11 10:18:28,937 - INFO - updating import rate for external metabolite cpd03808_m
# 2024-11-11 10:18:28,938 - INFO - updating import rate for external metabolite cpd90008_m
# 2024-11-11 10:18:28,940 - INFO - updating import rate for external metabolite cpd00001_m
# 2024-11-11 10:18:28,941 - INFO - updating import rate for external metabolite cpd90005_m
# 2024-11-11 10:18:28,943 - INFO - updating import rate for external metabolite cpd90007_m
# 2024-11-11 10:18:28,944 - INFO - updating import rate for external metabolite cpd90006_m
# 2024-11-11 10:18:28,946 - INFO - adding metabolite cpd23431_m to external medium
# 2024-11-11 10:18:28,949 - INFO - adding metabolite cpd23430_m to external medium
# 2024-11-11 10:18:28,951 - INFO - updating import rate for external metabolite cpd00155_m
# 2024-11-11 10:18:28,953 - INFO - updating import rate for external metabolite cpd00011_m
# 2024-11-11 10:18:28,955 - INFO - updating import rate for external metabolite cpd00007_m
# 2024-11-11 10:18:28,956 - INFO - updating import rate for external metabolite cpd01981_m
# 2024-11-11 10:18:28,958 - INFO - updating import rate for external metabolite cpd00141_m
# 2024-11-11 10:18:28,960 - INFO - updating import rate for external metabolite cpd00073_m
# 2024-11-11 10:18:28,961 - INFO - updating import rate for external metabolite cpd01861_m
# 2024-11-11 10:18:28,963 - INFO - updating import rate for external metabolite cpd00453_m
# 2024-11-11 10:18:28,965 - INFO - updating import rate for external metabolite cpd00071_m
# 2024-11-11 10:18:28,966 - INFO - updating import rate for external metabolite cpd00150_m
# 2024-11-11 10:18:28,968 - INFO - updating import rate for external metabolite cpd08021_m
# 2024-11-11 10:18:28,969 - INFO - updating import rate for external metabolite cpd00450_m
# 2024-11-11 10:18:28,971 - INFO - updating import rate for external metabolite cpd00055_m
# 2024-11-11 10:18:28,976 - INFO - updating import rate for external metabolite cpd00448_m
# 2024-11-11 10:18:28,978 - INFO - updating import rate for external metabolite cpd00025_m
# 2024-11-11 10:18:28,980 - INFO - updating import rate for external metabolite cpd00239_m
# 2024-11-11 10:18:28,981 - INFO - updating import rate for external metabolite cpd11640_m
# 2024-11-11 10:18:28,982 - INFO - updating import rate for external metabolite cpd00359_m
# 2024-11-11 10:18:28,984 - INFO - updating import rate for external metabolite cpd00659_m
# 2024-11-11 10:18:28,986 - INFO - updating import rate for external metabolite cpd00418_m
# 2024-11-11 10:18:28,988 - INFO - updating import rate for external metabolite cpd00371_m
# 2024-11-11 10:18:28,989 - INFO - updating import rate for external metabolite cpd00811_m
# 2024-11-11 10:18:28,991 - INFO - updating import rate for external metabolite cpd00324_m
# 2024-11-11 10:18:28,992 - INFO - updating import rate for external metabolite cpd01024_m
# 2024-11-11 10:18:28,994 - INFO - updating import rate for external metabolite cpd00204_m
# 2024-11-11 10:18:28,996 - INFO - updating import rate for external metabolite cpd00116_m
# 2024-11-11 10:18:28,998 - INFO - updating import rate for external metabolite cpd00528_m
# 2024-11-11 10:18:28,999 - INFO - updating import rate for external metabolite cpd11632_m
# 2024-11-11 10:18:29,001 - INFO - updating import rate for external metabolite cpd03662_m
# 2024-11-11 10:18:29,002 - INFO - updating import rate for external metabolite cpd00178_m
# 2024-11-11 10:18:29,004 - INFO - updating import rate for external metabolite cpd01618_m
# 2024-11-11 10:18:29,006 - INFO - updating import rate for external metabolite cpd00122_m
# 2024-11-11 10:18:29,008 - INFO - updating import rate for external metabolite cpd00137_m
# 2024-11-11 10:18:29,010 - INFO - updating import rate for external metabolite cpd00047_m
# 2024-11-11 10:18:29,011 - INFO - adding metabolite cpd00065_m to external medium
# 2024-11-11 10:18:29,014 - INFO - adding metabolite cpd00069_m to external medium
# 2024-11-11 10:18:29,016 - INFO - updating import rate for external metabolite cpd00276_m
# 2024-11-11 10:18:29,018 - INFO - adding metabolite cpd00221_m to external medium
# 2024-11-11 10:18:29,020 - INFO - updating import rate for external metabolite cpd00222_m
# 2024-11-11 10:18:29,021 - INFO - adding metabolite cpd00003_m to external medium
# 2024-11-11 10:18:29,023 - INFO - updating import rate for external metabolite cpd00130_m
# 2024-11-11 10:18:29,024 - INFO - adding metabolite cpd00136_m to external medium
# 2024-11-11 10:18:29,026 - INFO - updating import rate for external metabolite cpd00210_m
# 2024-11-11 10:18:29,028 - INFO - adding metabolite cpd00644_m to external medium
# 2024-11-11 10:18:29,030 - INFO - updating import rate for external metabolite cpd00653_m
# 2024-11-11 10:18:29,032 - INFO - adding metabolite cpd00526_m to external medium
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
#rename medium compounds for comunity
def transform_medium(medium_dict):
    """
    Transforms the keys of the medium dictionary from 'EX_cpdXXXXX_e0' to 'cpdXXXXX_m'.

    Parameters:
    - medium_dict (dict): Original medium dictionary with keys like 'EX_cpdXXXXX_e0'.

    Returns:
    - dict: New dictionary with keys transformed to 'cpdXXXXX_m'.
    """
    transformed_dict = {}
    for key, value in medium_dict.items():
        if key.startswith('EX_') and key.endswith('_e0'):
            compound_id = key[3:-3]  # Extract 'cpdXXXXX' from 'EX_cpdXXXXX_e0'
            new_key = f"EX_{compound_id}_m"  # Form the new key 'cpdXXXXX_m'
            transformed_dict[new_key] = value
        else:
            # Handle keys that don't match the expected format
            transformed_dict[key] = value
    return transformed_dict
medium4com = transform_medium(medium)

# %%
medium4com
# Out:
# {'EX_cpd00058_m': 1000.0,
#  'EX_cpd00104_m': 1000.0,
#  'EX_cpd00063_m': 1000.0,
#  'EX_cpd00099_m': 1000.0,
#  'EX_cpd00149_m': 1000.0,
#  'EX_cpd10515_m': 1000.0,
#  'EX_cpd10516_m': 1000.0,
#  'EX_cpd00067_m': 1000.0,
#  'EX_cpd00001_m': 1000.0,
#  'EX_cpd00205_m': 1000.0,
#  'EX_cpd00254_m': 1000.0,
#  'EX_cpd00030_m': 1000.0,
#  'EX_cpd11574_m': 1000.0,
#  'EX_cpd00244_m': 1000.0,
#  'EX_cpd00209_m': 1000.0,
#  'EX_cpd00009_m': 1000.0,
#  'EX_cpd00048_m': 1000.0,
#  'EX_cpd00305_m': 1000.0,
#  'EX_cpd00034_m': 1000.0,
#  'EX_cpd11632_m': 1000.0,
#  'EX_cpd00011_m': 1000.0,
#  'EX_cpd00007_m': 1000.0,
#  'EX_cpd00528_m': 1000.0}

# %%
# Optimize the community model for growth
community.solver = 'glpk'
community.medium = transform_medium(adjusted_medium)
solution = community.optimize()
print(f"Community growth rate: {solution.objective_value}")

# Check if the optimization was successful
if solution.status == 'optimal':
    print("Optimization successful.")
else:
    print(f"Optimization status: {solution.status}")
# Out:
# Community growth rate: 0.17662547917824253
# Optimization successful.

# %%
for model_id in community.compartments:
    print(model_id)
    # model = community.metabolites.get_by_any(model_id)
    # # Alternatively, access the model directly if accessible
    # model = community.get_model(model_id)
    # print(f"Model ID: {model.id}")
    # print(f"Number of reactions: {len(model.reactions)}")
    # print(f"Number of metabolites: {len(model.metabolites)}")
    # print("-" * 40)
# Out:
# c0__bin_5
# e0__bin_5
# p0__bin_5
# m
# c0__bin_6
# e0__bin_6
# p0__bin_6

# %%
from micom.workflows import grow
res = grow(model_folder="models", medium=medium, tradeoff=0.5, threads=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 2
#       1 from micom.workflows import grow
# ----> 2 res = grow(model_folder="models", medium=medium, tradeoff=0.5, threads=2)
#
# TypeError: grow() missing 1 required positional argument: 'manifest'

# %%
import micom
from micom import intercation

# Compute pairwise interactions
pairwise_interactions = community.interactions()

# Display the interactions DataFrame
print("\nPairwise Interactions Between Community Members:")
print(pairwise_interactions)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[180], line 2
#       1 import micom
# ----> 2 from micom import intercation
#       4 # Compute pairwise interactions
#       5 pairwise_interactions = community.interactions()
#
# ImportError: cannot import name 'intercation' from 'micom' (/mnt/workspace/miniconda3/envs/snakemake/lib/python3.11/site-packages/micom/__init__.py)
