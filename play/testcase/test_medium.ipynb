# %% [markdown]
# #

# %%
# Standard library imports
import os
import shutil
import glob
from pathlib import Path
import logging


# Third-party library imports
import micom
from micom import Community
from cobra import Reaction, Metabolite, Model
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import cobra

# %%
# params
model_db_path = Path("./models/")       # Replace with your actual model directory path
adjusted_models_path = Path("./adjusted_models")  # Replace with your desired output directory path

# Define the medium composition
medium = {
    'EX_cpd00058_e0': 1000.0,   # Cu2+
    'EX_cpd00104_e0': 1000.0,   # Biotin
    'EX_cpd00063_e0': 1000.0,   # Ca2+
    'EX_cpd00099_e0': 1000.0,   # Cl-
    'EX_cpd00149_e0': 1000.0,   # Cobalt
    'EX_cpd10515_e0': 1000.0,   # Fe2+
    'EX_cpd10516_e0': 1000.0,   # Fe3+
    'EX_cpd00067_e0': 1000.0,   # H+
    'EX_cpd00001_e0': 1000.0,   # H2O
    'EX_cpd00205_e0': 1000.0,   # K+
    'EX_cpd00254_e0': 1000.0,   # Mg
    'EX_cpd00030_e0': 1000.0,   # Mn2+
    'EX_cpd11574_e0': 1000.0,   # Molybdate
    'EX_cpd00244_e0': 1000.0,   # Nickel
    'EX_cpd00209_e0': 1000.0,   # Nitrate
    'EX_cpd00009_e0': 1000.0,   # Phosphate
    'EX_cpd00048_e0': 1000.0,   # Sulfate
    'EX_cpd00305_e0': 1000.0,   # Thiamin
    'EX_cpd00034_e0': 1000.0,   # Zn2+
    'EX_cpd11632_e0': 1000.0,   # Photon
    'EX_cpd00011_e0': 1000.0,   # CO2
    'EX_cpd00007_e0': 1000.0,   # O2
    'EX_cpd00528_e0': 1000.0,   # N2
}

# %%
# ----------------------------
# Configure Logging
# ----------------------------

# First, get the root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Set the desired logging level

# Remove any existing handlers to prevent duplicate logs
if logger.hasHandlers():
    logger.handlers.clear()

# Create a file handler to save logs to a file
file_handler = logging.FileHandler('model_processing.log')
file_handler.setLevel(logging.INFO)

# Create a stream handler to print logs to the Jupyter cell
stream_handler = logging.StreamHandler()
stream_handler.setLevel(logging.INFO)

# Define a common formatter
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Assign the formatter to both handlers
file_handler.setFormatter(formatter)
stream_handler.setFormatter(formatter)

# Add both handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(stream_handler)



def adjust_medium(model, medium):
    """
    Adjust the medium for the given model based on available exchange reactions.
    """
    adjusted_medium = {}
    available_exchanges = {rxn.id for rxn in model.exchanges}
    for rxn_id, value in medium.items():
        if rxn_id in available_exchanges:
            adjusted_medium[rxn_id] = value
        else:
            logging.warning(f"Exchange reaction {rxn_id} not found in model {model.id}")
    return adjusted_medium

def add_exchange_reaction(model, metabolite_id_base, lower_bound=-1000, upper_bound=1000):
    """
    Adds an exchange reaction for a metabolite, creating external and transport reactions if necessary.
    """
    # Build metabolite IDs
    internal_met_id = f"M_{metabolite_id_base}_c0"
    external_met_id = f"M_{metabolite_id_base}_e0"
    exchange_rxn_id = f"EX_M_{metabolite_id_base}_e0"
    transport_rxn_id = f"TRANS_M_{metabolite_id_base}"
    
    # Check if the internal metabolite exists
    try:
        internal_met = model.metabolites.get_by_id(internal_met_id)
    except KeyError:
        logging.error(f"Internal metabolite {internal_met_id} not found in model {model.id}. Cannot proceed.")
        return
    
    # Check if the external metabolite exists; if not, create it
    external_met = model.metabolites.get_by_id(external_met_id, None)
    if external_met is None:
        external_met = Metabolite(
            id=external_met_id,
            formula=internal_met.formula,
            name=internal_met.name,
            compartment='e0'
        )
        model.add_metabolites([external_met])
        logging.info(f"Added external metabolite {external_met_id} to model {model.id}")
    
    # Add the transport reaction if it doesn't exist
    if transport_rxn_id not in model.reactions:
        transport_rxn = Reaction(id=transport_rxn_id)
        transport_rxn.name = f"Transport of {internal_met.name}"
        transport_rxn.lower_bound = -1000
        transport_rxn.upper_bound = 1000
        transport_rxn.add_metabolites({internal_met: -1, external_met: 1})
        model.add_reactions([transport_rxn])
        logging.info(f"Added transport reaction {transport_rxn_id} to model {model.id}")
    
    # Add the exchange reaction if it doesn't exist
    if exchange_rxn_id not in model.reactions:
        exchange_rxn = Reaction(id=exchange_rxn_id)
        exchange_rxn.name = f"Exchange of {external_met.name}"
        exchange_rxn.lower_bound = lower_bound
        exchange_rxn.upper_bound = upper_bound
        exchange_rxn.add_metabolites({external_met: -1})
        model.add_reactions([exchange_rxn])
        logging.info(f"Added exchange reaction {exchange_rxn_id} to model {model.id}")
    else:
        logging.info(f"Exchange reaction {exchange_rxn_id} already exists in model {model.id}")

def add_all_exchange_reactions(model, medium):
    """
    Add exchange reactions for all components defined in the medium.
    """
    for rxn_id in medium.keys():
        if rxn_id not in model.reactions:
            # Infer metabolite ID by removing 'EX_' prefix
            if rxn_id.startswith('EX_'):
                metabolite_id = rxn_id[3:]
                if metabolite_id in model.metabolites:
                    add_exchange_reaction(model, metabolite_id, reaction_id=rxn_id)
                else:
                    logging.warning(f"Metabolite {metabolite_id} corresponding to {rxn_id} not found in model {model.id}. Exchange reaction {rxn_id} not added.")
            else:
                logging.warning(f"Reaction ID {rxn_id} does not follow the 'EX_' prefix convention. Skipping.")

def process_model(model_path, output_dir, medium):
    """
    Load a model, adjust it by adding exchange reactions for all medium components,
    set the medium, optimize the model, and save the adjusted model to the output directory.
    """
    try:
        # Load the model using micom.util.load_model (keeping it as is)
        model = micom.util.load_model(str(model_path))
        logging.info(f"\nProcessing model: {model.id}")

        # Add exchange reactions for all medium components
        add_all_exchange_reactions(model, medium)

        # Adjust the medium
        adjusted_medium = adjust_medium(model, medium)
        model.medium = adjusted_medium

        # Optional: Optimize the model to ensure it can grow
        solution = model.optimize()
        logging.info(f"Model {model.id} growth rate after adjustment: {solution.objective_value}")

        # Save the adjusted model using the existing save function
        output_model_path = output_dir / model_path.name
        write_sbml_model(model, output_model_path)  # Keeping the saving function as is
        logging.info(f"Saved adjusted model to {output_model_path}")

    except Exception as e:
        logging.error(f"Failed to process model {model_path.name}: {e}")


"""
Main function to process all models in the specified directory.
"""
# Iterate through all files in the model_db_path
for model_file in model_db_path.iterdir():
    # Check if the file is an XML file (common format for metabolic models)
    if model_file.suffix.lower() in ['.xml']:
        process_model(model_file, adjusted_models_path, medium)
    else:
        logging.warning(f"Skipping unsupported file format: {model_file.name}")

logging.info("\nAll models have been processed.")

# ----------------------------
# Copy Manifest File to the Output Directory
# ----------------------------

# Define the manifest file name (adjust if your manifest file has a different name)
manifest_filename = "manifest.csv"  # Replace with the actual manifest file name if different

# Define the source and destination paths for the manifest file
source_manifest = model_db_path / manifest_filename
destination_manifest = adjusted_models_path / manifest_filename

# Check if the manifest file exists in the source directory
if source_manifest.exists():
    try:
        shutil.copy2(source_manifest, destination_manifest)
        logging.info(f"Copied manifest file to {destination_manifest}")
    except Exception as e:
        logging.error(f"Failed to copy manifest file: {e}")
else:
    logging.warning(f"Manifest file {manifest_filename} not found in {model_db_path}. No manifest copied.")
# Out:
# 2024-11-11 10:56:30,033 - INFO - reading model from models/bin.5.xml
# 2024-11-11 10:56:33,526 - INFO -
# Processing model: bin_5
# 2024-11-11 10:56:33,528 - WARNING - Metabolite cpd00104_e0 corresponding to EX_cpd00104_e0 not found in model bin_5. Exchange reaction EX_cpd00104_e0 not added.
# 2024-11-11 10:56:33,536 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:56:33,545 - WARNING - Exchange reaction EX_cpd00104_e0 not found in model bin_5
# 2024-11-11 10:56:33,550 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:56:33,622 - INFO - Model bin_5 growth rate after adjustment: 0.0
# 2024-11-11 10:56:35,698 - INFO - Saved adjusted model to adjusted_models/bin.5.xml
# 2024-11-11 10:56:35,722 - INFO - reading model from models/bin.6.xml
# 2024-11-11 10:56:38,971 - INFO -
# Processing model: bin_6
# 2024-11-11 10:56:38,973 - WARNING - Metabolite cpd00104_e0 corresponding to EX_cpd00104_e0 not found in model bin_6. Exchange reaction EX_cpd00104_e0 not added.
# 2024-11-11 10:56:38,981 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:56:38,988 - WARNING - Exchange reaction EX_cpd00104_e0 not found in model bin_6
# 2024-11-11 10:56:38,993 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:56:39,077 - INFO - Model bin_6 growth rate after adjustment: 2.9808737165593997
# 2024-11-11 10:56:40,994 - INFO - Saved adjusted model to adjusted_models/bin.6.xml
# 2024-11-11 10:56:41,032 - WARNING - Skipping unsupported file format: .ipynb_checkpoints
# 2024-11-11 10:56:41,033 - WARNING - Skipping unsupported file format: manifest.csv
# 2024-11-11 10:56:41,033 - INFO -
# All models have been processed.
# 2024-11-11 10:56:41,036 - INFO - Copied manifest file to adjusted_models/manifest.csv

# %%
# Combine Individual Models into a Community Model
import pandas as pd
# Create the taxonomy DataFrame
taxonomy = pd.DataFrame({
    'id': ['bin.5','bin.6'],
    'abundance': [0.5,0.5],
    'phylum': ['Firmicutes','Cyanobacteria']
})

# Specify the directory containing your model files

# Create the community model
community = Community (
    taxonomy,
     model_db=str(adjusted_models_path)
)
# Out:
# 2024-11-11 10:56:52,430 - INFO - building new micom model None.
# 2024-11-11 10:56:52,432 - INFO - using the cplex solver.
# 2024-11-11 10:56:52,439 - INFO - 0 individuals with abundances below threshold
# 2024-11-11 10:56:52,449 - INFO - Matched 100% of total abundance in model DB.
# Output()
# 2024-11-11 10:56:52,506 - INFO - reading model from adjusted_models/bin.5.xml
# 2024-11-11 10:56:55,876 - INFO - converting IDs for bin_5
# 2024-11-11 10:56:55,885 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:56:55,886 - INFO - Identified e0 as the external compartment for bin_5. If that is wrong you may be in trouble...
# 2024-11-11 10:57:01,424 - INFO - adding reactions for bin_5 to community
# 2024-11-11 10:57:02,162 - INFO - adding metabolite cpd00001_m to external medium
# 2024-11-11 10:57:02,165 - INFO - adding metabolite cpd00418_m to external medium
# 2024-11-11 10:57:02,167 - INFO - adding metabolite cpd00075_m to external medium
# 2024-11-11 10:57:02,169 - INFO - adding metabolite cpd00009_m to external medium
# 2024-11-11 10:57:02,171 - INFO - adding metabolite cpd00023_m to external medium
# 2024-11-11 10:57:02,177 - INFO - adding metabolite cpd00027_m to external medium
# 2024-11-11 10:57:02,179 - INFO - adding metabolite cpd00028_m to external medium
# 2024-11-11 10:57:02,181 - INFO - adding metabolite cpd00030_m to external medium
# 2024-11-11 10:57:02,183 - INFO - adding metabolite cpd00034_m to external medium
# 2024-11-11 10:57:02,186 - INFO - adding metabolite cpd00039_m to external medium
# 2024-11-11 10:57:02,188 - INFO - adding metabolite cpd00041_m to external medium
# 2024-11-11 10:57:02,191 - INFO - adding metabolite cpd00048_m to external medium
# 2024-11-11 10:57:02,193 - INFO - adding metabolite cpd00051_m to external medium
# 2024-11-11 10:57:02,195 - INFO - adding metabolite cpd00053_m to external medium
# 2024-11-11 10:57:02,197 - INFO - adding metabolite cpd00064_m to external medium
# 2024-11-11 10:57:02,198 - INFO - adding metabolite cpd00073_m to external medium
# 2024-11-11 10:57:02,200 - INFO - adding metabolite cpd00098_m to external medium
# 2024-11-11 10:57:02,202 - INFO - adding metabolite cpd00105_m to external medium
# 2024-11-11 10:57:02,203 - INFO - adding metabolite cpd00108_m to external medium
# 2024-11-11 10:57:02,206 - INFO - adding metabolite cpd00118_m to external medium
# 2024-11-11 10:57:02,208 - INFO - adding metabolite cpd00119_m to external medium
# 2024-11-11 10:57:02,210 - INFO - adding metabolite cpd00129_m to external medium
# 2024-11-11 10:57:02,212 - INFO - adding metabolite cpd00149_m to external medium
# 2024-11-11 10:57:02,214 - INFO - adding metabolite cpd00154_m to external medium
# 2024-11-11 10:57:02,216 - INFO - adding metabolite cpd00156_m to external medium
# 2024-11-11 10:57:02,218 - INFO - adding metabolite cpd00161_m to external medium
# 2024-11-11 10:57:02,460 - INFO - adding metabolite cpd11632_m to external medium
# 2024-11-11 10:57:02,462 - INFO - adding metabolite cpd03662_m to external medium
# 2024-11-11 10:57:02,465 - INFO - adding metabolite cpd00178_m to external medium
# 2024-11-11 10:57:02,467 - INFO - adding metabolite cpd01618_m to external medium
# 2024-11-11 10:57:02,469 - INFO - adding metabolite cpd00276_m to external medium
# 2024-11-11 10:57:02,471 - INFO - adding metabolite cpd00107_m to external medium
# 2024-11-11 10:57:02,472 - INFO - adding metabolite cpd01017_m to external medium
# 2024-11-11 10:57:02,473 - INFO - adding metabolite cpd00210_m to external medium
# 2024-11-11 10:57:02,475 - INFO - adding metabolite cpd15605_m to external medium
# 2024-11-11 10:57:02,476 - INFO - adding metabolite cpd00122_m to external medium
# 2024-11-11 10:57:02,478 - INFO - adding metabolite cpd00322_m to external medium
# 2024-11-11 10:57:02,480 - INFO - adding metabolite cpd00793_m to external medium
# 2024-11-11 10:57:02,483 - INFO - adding metabolite cpd00099_m to external medium
# 2024-11-11 10:57:02,485 - INFO - adding metabolite cpd00010_m to external medium
# 2024-11-11 10:57:02,487 - INFO - adding metabolite cpd00038_m to external medium
# 2024-11-11 10:57:02,489 - INFO - adding metabolite cpd00380_m to external medium
# 2024-11-11 10:57:02,496 - INFO - adding metabolite cpd00060_m to external medium
# 2024-11-11 10:57:02,498 - INFO - adding metabolite cpd00366_m to external medium
# 2024-11-11 10:57:02,502 - INFO - adding metabolite cpd00222_m to external medium
# 2024-11-11 10:57:02,504 - INFO - adding metabolite cpd00081_m to external medium
# 2024-11-11 10:57:02,506 - INFO - adding metabolite cpd00017_m to external medium
# 2024-11-11 10:57:02,507 - INFO - adding metabolite cpd00130_m to external medium
# 2024-11-11 10:57:02,509 - INFO - adding metabolite cpd00653_m to external medium
# 2024-11-11 10:57:02,511 - INFO - reading model from adjusted_models/bin.6.xml
# 2024-11-11 10:57:05,635 - INFO - converting IDs for bin_6
# 2024-11-11 10:57:05,645 - INFO - Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# 2024-11-11 10:57:05,646 - INFO - Identified e0 as the external compartment for bin_6. If that is wrong you may be in trouble...
# 2024-11-11 10:57:10,234 - INFO - adding reactions for bin_6 to community
# 2024-11-11 10:57:11,533 - INFO - updating import rate for external metabolite cpd00009_m
# 2024-11-11 10:57:11,536 - INFO - updating import rate for external metabolite cpd00023_m
# 2024-11-11 10:57:11,537 - INFO - updating import rate for external metabolite cpd00027_m
# 2024-11-11 10:57:11,539 - INFO - updating import rate for external metabolite cpd00028_m
# 2024-11-11 10:57:11,540 - INFO - updating import rate for external metabolite cpd00030_m
# 2024-11-11 10:57:11,542 - INFO - updating import rate for external metabolite cpd00034_m
# 2024-11-11 10:57:11,544 - INFO - updating import rate for external metabolite cpd00039_m
# 2024-11-11 10:57:11,545 - INFO - updating import rate for external metabolite cpd00041_m
# 2024-11-11 10:57:11,547 - INFO - updating import rate for external metabolite cpd00048_m
# 2024-11-11 10:57:11,549 - INFO - updating import rate for external metabolite cpd00051_m
# 2024-11-11 10:57:11,550 - INFO - updating import rate for external metabolite cpd00053_m
# 2024-11-11 10:57:11,552 - INFO - updating import rate for external metabolite cpd00064_m
# 2024-11-11 10:57:11,554 - INFO - updating import rate for external metabolite cpd00098_m
# 2024-11-11 10:57:11,556 - INFO - updating import rate for external metabolite cpd00105_m
# 2024-11-11 10:57:11,557 - INFO - updating import rate for external metabolite cpd00107_m
# 2024-11-11 10:57:11,559 - INFO - updating import rate for external metabolite cpd00108_m
# 2024-11-11 10:57:11,562 - INFO - updating import rate for external metabolite cpd00118_m
# 2024-11-11 10:57:11,568 - INFO - updating import rate for external metabolite cpd00119_m
# 2024-11-11 10:57:11,570 - INFO - updating import rate for external metabolite cpd00129_m
# 2024-11-11 10:57:11,572 - INFO - updating import rate for external metabolite cpd00149_m
# 2024-11-11 10:57:11,574 - INFO - updating import rate for external metabolite cpd00154_m
# 2024-11-11 10:57:11,576 - INFO - updating import rate for external metabolite cpd00156_m
# 2024-11-11 10:57:11,577 - INFO - updating import rate for external metabolite cpd00161_m
# 2024-11-11 10:57:11,579 - INFO - updating import rate for external metabolite cpd00179_m
# 2024-11-11 10:57:11,581 - INFO - updating import rate for external metabolite cpd00224_m
# 2024-11-11 10:57:11,582 - INFO - updating import rate for external metabolite cpd00244_m
# 2024-11-11 10:57:11,584 - INFO - updating import rate for external metabolite cpd00264_m
# 2024-11-11 10:57:11,586 - INFO - updating import rate for external metabolite cpd00268_m
# 2024-11-11 10:57:11,587 - INFO - updating import rate for external metabolite cpd00322_m
# 2024-11-11 10:57:11,589 - INFO - updating import rate for external metabolite cpd00540_m
# 2024-11-11 10:57:11,591 - INFO - adding metabolite cpd03724_m to external medium
# 2024-11-11 10:57:11,594 - INFO - updating import rate for external metabolite cpd10516_m
# 2024-11-11 10:57:11,595 - INFO - updating import rate for external metabolite cpd00067_m
# 2024-11-11 10:57:11,597 - INFO - updating import rate for external metabolite cpd00367_m
# 2024-11-11 10:57:11,599 - INFO - updating import rate for external metabolite cpd00311_m
# 2024-11-11 10:57:11,601 - INFO - updating import rate for external metabolite cpd00060_m
# 2024-11-11 10:57:11,602 - INFO - updating import rate for external metabolite cpd00220_m
# 2024-11-11 10:57:11,604 - INFO - updating import rate for external metabolite cpd00084_m
# 2024-11-11 10:57:11,606 - INFO - updating import rate for external metabolite cpd00971_m
# 2024-11-11 10:57:11,608 - INFO - updating import rate for external metabolite cpd00054_m
# 2024-11-11 10:57:11,609 - INFO - updating import rate for external metabolite cpd00246_m
# 2024-11-11 10:57:11,611 - INFO - updating import rate for external metabolite cpd00182_m
# 2024-11-11 10:57:11,613 - INFO - updating import rate for external metabolite cpd00013_m
# 2024-11-11 10:57:11,615 - INFO - updating import rate for external metabolite cpd00020_m
# 2024-11-11 10:57:11,616 - INFO - updating import rate for external metabolite cpd00029_m
# 2024-11-11 10:57:11,618 - INFO - updating import rate for external metabolite cpd04098_m
# 2024-11-11 10:57:11,620 - INFO - updating import rate for external metabolite cpd00063_m
# 2024-11-11 10:57:11,621 - INFO - updating import rate for external metabolite cpd01012_m
# 2024-11-11 10:57:11,623 - INFO - updating import rate for external metabolite cpd00058_m
# 2024-11-11 10:57:11,625 - INFO - updating import rate for external metabolite cpd00363_m
# 2024-11-11 10:57:11,626 - INFO - updating import rate for external metabolite cpd10515_m
# 2024-11-11 10:57:11,628 - INFO - updating import rate for external metabolite cpd00082_m
# 2024-11-11 10:57:11,630 - INFO - updating import rate for external metabolite cpd00106_m
# 2024-11-11 10:57:11,632 - INFO - updating import rate for external metabolite cpd00121_m
# 2024-11-11 10:57:11,633 - INFO - updating import rate for external metabolite cpd00205_m
# 2024-11-11 10:57:11,635 - INFO - updating import rate for external metabolite cpd00208_m
# 2024-11-11 10:57:11,637 - INFO - updating import rate for external metabolite cpd01262_m
# 2024-11-11 10:57:11,639 - INFO - updating import rate for external metabolite cpd11574_m
# 2024-11-11 10:57:11,640 - INFO - updating import rate for external metabolite cpd00075_m
# 2024-11-11 10:57:11,642 - INFO - updating import rate for external metabolite cpd00209_m
# 2024-11-11 10:57:11,644 - INFO - updating import rate for external metabolite cpd01132_m
# 2024-11-11 10:57:11,645 - INFO - updating import rate for external metabolite cpd00396_m
# 2024-11-11 10:57:11,647 - INFO - updating import rate for external metabolite cpd00036_m
# 2024-11-11 10:57:11,649 - INFO - updating import rate for external metabolite cpd01217_m
# 2024-11-11 10:57:11,650 - INFO - updating import rate for external metabolite cpd00751_m
# 2024-11-11 10:57:11,652 - INFO - updating import rate for external metabolite cpd00035_m
# 2024-11-11 10:57:11,654 - INFO - updating import rate for external metabolite cpd00132_m
# 2024-11-11 10:57:11,655 - INFO - updating import rate for external metabolite cpd00099_m
# 2024-11-11 10:57:11,657 - INFO - updating import rate for external metabolite cpd00277_m
# 2024-11-11 10:57:11,659 - INFO - updating import rate for external metabolite cpd01107_m
# 2024-11-11 10:57:11,661 - INFO - updating import rate for external metabolite cpd01741_m
# 2024-11-11 10:57:11,662 - INFO - updating import rate for external metabolite cpd03847_m
# 2024-11-11 10:57:11,664 - INFO - updating import rate for external metabolite cpd15298_m
# 2024-11-11 10:57:11,669 - INFO - updating import rate for external metabolite cpd00214_m
# 2024-11-11 10:57:11,672 - INFO - updating import rate for external metabolite cpd15237_m
# 2024-11-11 10:57:11,674 - INFO - updating import rate for external metabolite cpd01080_m
# 2024-11-11 10:57:11,675 - INFO - updating import rate for external metabolite cpd15269_m
# 2024-11-11 10:57:11,677 - INFO - updating import rate for external metabolite cpd01113_m
# 2024-11-11 10:57:11,679 - INFO - updating import rate for external metabolite cpd03846_m
# 2024-11-11 10:57:11,680 - INFO - updating import rate for external metabolite cpd00531_m
# 2024-11-11 10:57:11,682 - INFO - updating import rate for external metabolite cpd03587_m
# 2024-11-11 10:57:11,684 - INFO - updating import rate for external metabolite cpd01399_m
# 2024-11-11 10:57:11,686 - INFO - updating import rate for external metabolite cpd00254_m
# 2024-11-11 10:57:11,687 - INFO - updating import rate for external metabolite cpd00305_m
# 2024-11-11 10:57:11,689 - INFO - updating import rate for external metabolite cpd04097_m
# 2024-11-11 10:57:11,691 - INFO - updating import rate for external metabolite cpd00185_m
# 2024-11-11 10:57:11,692 - INFO - updating import rate for external metabolite cpd00010_m
# 2024-11-11 10:57:11,694 - INFO - updating import rate for external metabolite cpd15494_m
# 2024-11-11 10:57:11,696 - INFO - updating import rate for external metabolite cpd00794_m
# 2024-11-11 10:57:11,697 - INFO - updating import rate for external metabolite cpd00033_m
# 2024-11-11 10:57:11,699 - INFO - updating import rate for external metabolite cpd11976_m
# 2024-11-11 10:57:11,701 - INFO - updating import rate for external metabolite cpd00133_m
# 2024-11-11 10:57:11,703 - INFO - updating import rate for external metabolite cpd00006_m
# 2024-11-11 10:57:11,704 - INFO - updating import rate for external metabolite cpd11451_m
# 2024-11-11 10:57:11,706 - INFO - updating import rate for external metabolite cpd11606_m
# 2024-11-11 10:57:11,708 - INFO - updating import rate for external metabolite cpd17026_m
# 2024-11-11 10:57:11,709 - INFO - updating import rate for external metabolite cpd17027_m
# 2024-11-11 10:57:11,711 - INFO - adding metabolite cpd01048_m to external medium
# 2024-11-11 10:57:11,714 - INFO - updating import rate for external metabolite cpd00281_m
# 2024-11-11 10:57:11,715 - INFO - updating import rate for external metabolite cpd00138_m
# 2024-11-11 10:57:11,717 - INFO - updating import rate for external metabolite cpd00314_m
# 2024-11-11 10:57:11,719 - INFO - updating import rate for external metabolite cpd01133_m
# 2024-11-11 10:57:11,720 - INFO - adding metabolite cpd02733_m to external medium
# 2024-11-11 10:57:11,723 - INFO - updating import rate for external metabolite cpd01354_m
# 2024-11-11 10:57:11,725 - INFO - updating import rate for external metabolite cpd03808_m
# 2024-11-11 10:57:11,726 - INFO - updating import rate for external metabolite cpd90008_m
# 2024-11-11 10:57:11,728 - INFO - updating import rate for external metabolite cpd00001_m
# 2024-11-11 10:57:11,730 - INFO - updating import rate for external metabolite cpd90005_m
# 2024-11-11 10:57:11,731 - INFO - updating import rate for external metabolite cpd90007_m
# 2024-11-11 10:57:11,733 - INFO - updating import rate for external metabolite cpd90006_m
# 2024-11-11 10:57:11,735 - INFO - adding metabolite cpd23431_m to external medium
# 2024-11-11 10:57:11,737 - INFO - adding metabolite cpd23430_m to external medium
# 2024-11-11 10:57:11,740 - INFO - updating import rate for external metabolite cpd00155_m
# 2024-11-11 10:57:11,741 - INFO - updating import rate for external metabolite cpd00011_m
# 2024-11-11 10:57:11,743 - INFO - updating import rate for external metabolite cpd00007_m
# 2024-11-11 10:57:11,745 - INFO - updating import rate for external metabolite cpd01981_m
# 2024-11-11 10:57:11,746 - INFO - updating import rate for external metabolite cpd00141_m
# 2024-11-11 10:57:11,748 - INFO - updating import rate for external metabolite cpd00073_m
# 2024-11-11 10:57:11,750 - INFO - updating import rate for external metabolite cpd01861_m
# 2024-11-11 10:57:11,752 - INFO - updating import rate for external metabolite cpd00453_m
# 2024-11-11 10:57:11,753 - INFO - updating import rate for external metabolite cpd00071_m
# 2024-11-11 10:57:11,755 - INFO - updating import rate for external metabolite cpd00150_m
# 2024-11-11 10:57:11,757 - INFO - updating import rate for external metabolite cpd08021_m
# 2024-11-11 10:57:11,759 - INFO - updating import rate for external metabolite cpd00450_m
# 2024-11-11 10:57:11,761 - INFO - updating import rate for external metabolite cpd00055_m
# 2024-11-11 10:57:11,762 - INFO - updating import rate for external metabolite cpd00448_m
# 2024-11-11 10:57:11,764 - INFO - updating import rate for external metabolite cpd00025_m
# 2024-11-11 10:57:11,765 - INFO - updating import rate for external metabolite cpd00239_m
# 2024-11-11 10:57:11,767 - INFO - updating import rate for external metabolite cpd11640_m
# 2024-11-11 10:57:11,769 - INFO - updating import rate for external metabolite cpd00359_m
# 2024-11-11 10:57:11,773 - INFO - updating import rate for external metabolite cpd00659_m
# 2024-11-11 10:57:11,775 - INFO - updating import rate for external metabolite cpd00418_m
# 2024-11-11 10:57:11,777 - INFO - updating import rate for external metabolite cpd00371_m
# 2024-11-11 10:57:11,779 - INFO - updating import rate for external metabolite cpd00811_m
# 2024-11-11 10:57:11,780 - INFO - updating import rate for external metabolite cpd00324_m
# 2024-11-11 10:57:11,782 - INFO - updating import rate for external metabolite cpd01024_m
# 2024-11-11 10:57:11,784 - INFO - updating import rate for external metabolite cpd00204_m
# 2024-11-11 10:57:11,785 - INFO - updating import rate for external metabolite cpd00116_m
# 2024-11-11 10:57:11,787 - INFO - updating import rate for external metabolite cpd00528_m
# 2024-11-11 10:57:11,789 - INFO - updating import rate for external metabolite cpd11632_m
# 2024-11-11 10:57:11,791 - INFO - updating import rate for external metabolite cpd03662_m
# 2024-11-11 10:57:11,792 - INFO - updating import rate for external metabolite cpd00178_m
# 2024-11-11 10:57:11,794 - INFO - updating import rate for external metabolite cpd01618_m
# 2024-11-11 10:57:11,796 - INFO - updating import rate for external metabolite cpd00122_m
# 2024-11-11 10:57:11,798 - INFO - updating import rate for external metabolite cpd00137_m
# 2024-11-11 10:57:11,800 - INFO - updating import rate for external metabolite cpd00047_m
# 2024-11-11 10:57:11,801 - INFO - adding metabolite cpd00065_m to external medium
# 2024-11-11 10:57:11,804 - INFO - adding metabolite cpd00069_m to external medium
# 2024-11-11 10:57:11,807 - INFO - updating import rate for external metabolite cpd00276_m
# 2024-11-11 10:57:11,808 - INFO - adding metabolite cpd00221_m to external medium
# 2024-11-11 10:57:11,811 - INFO - updating import rate for external metabolite cpd00222_m
# 2024-11-11 10:57:11,813 - INFO - adding metabolite cpd00003_m to external medium
# 2024-11-11 10:57:11,815 - INFO - updating import rate for external metabolite cpd00130_m
# 2024-11-11 10:57:11,817 - INFO - adding metabolite cpd00136_m to external medium
# 2024-11-11 10:57:11,818 - INFO - updating import rate for external metabolite cpd00210_m
# 2024-11-11 10:57:11,820 - INFO - adding metabolite cpd00644_m to external medium
# 2024-11-11 10:57:11,822 - INFO - updating import rate for external metabolite cpd00653_m
# 2024-11-11 10:57:11,823 - INFO - adding metabolite cpd00526_m to external medium
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
